# %% [markdown]
# # **Exercise 2**
# **Name : Simon B. Sancon**
#
# **Section: BSCS-IS-3B**

# %% [markdown]
# # **1.Creating Dataset**

# %%
import pandas as pd

data = {
    'student_id': range(1,16),
    'gender': ["Male", "Female", "Male", "Male", "Female","Male", "Male", "Female", "Female", "Female", "Male", "Male", "Male", "Male", "Male"],
    'test_date': pd.date_range(start = "2024-02-14", periods= 15),
    'study_hours': [2,3,4,4,5,6,4,3,2,2,1,0,7,2,3],
    'test_score': [80,75,76,77,89,84,91,92,87,82,84,84,82,88,91],
    'attendance': ["Absent", "Present", "Present", "Present", "Absent", "Present", "Present", "Absent", "Present", "Present", "Present", "Present", "Present", "Present", "Present"]
}

df = pd.DataFrame(data)

df.to_csv("student_performance.csv", index = False)

# %% [markdown]
# # **2.  Data Loading and Initial Examination**

# %%
df = pd.read_csv("student_performance.csv")

print(df.head())
print(df.isnull().sum())
# Out:
#    student_id  gender   test_date  study_hours  test_score attendance
# 0           1    Male  2024-02-14            2          80     Absent
# 1           2  Female  2024-02-15            3          75    Present
# 2           3    Male  2024-02-16            4          76    Present
# 3           4    Male  2024-02-17            4          77    Present
# 4           5  Female  2024-02-18            5          89     Absent
# 5           6    Male  2024-02-19            6          84    Present
# 6           7    Male  2024-02-20            4          91    Present
# student_id     0
# gender         0
# test_date      0
# study_hours    0
# test_score     0
# attendance     0
# dtype: int64

# %% [markdown]
# # **3. Exploratory Data Analysis**

# %%
import matplotlib.pyplot as plt
import seaborn as sne

summary_stats = df[["test_score", "study_hours"]].describe()

#Histogram
plt.figure(figsize=(12,6))

plt.subplot(1,2,1)
sne.histplot(df["test_score"],bins=15, kde=True)
plt.title("Distribution of Test Score")

#ScatterPlot
plt.subplot(1,2,2)
sne.histplot(df["study_hours"],bins=15, kde=True)
plt.title("Distribution of Study Hours")

#ScatterPlot
plt.figure(figsize=(8,6))
sne.scatterplot(data = df, x = "study_hours", y = "test_score")
plt.title("Scatter Plot of Study Hours vs. Test Scores")
# Out:
# Text(0.5, 1.0, 'Scatter Plot of Study Hours vs. Test Scores')

# %% [markdown]
# # **4. Data Visualization**

# %%
plt.figure(figsize=(6,4))
sne.countplot(data=df, x= "gender")
plt.title("Gender Distribution")

plt.figure(figsize=(10, 8))
sne.lineplot(data = df, x = "test_date", y = "test_score")
plt.title("Trend in Test Score Over Time")
plt.xticks(rotation = 45)

correlation_matrix = df[["study_hours", "test_score", "attendance"]].corr()
plt.figure(figsize=(8,6))
sne.heatmap(correlation_matrix, annot = True, cmap="coolwarm")
plt.title("Correlation Analyis")
# Out:
# <ipython-input-38-1dfea2df63ba>:10: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation_matrix = df[["study_hours", "test_score", "attendance"]].corr()
# Text(0.5, 1.0, 'Correlation Analyis')

# %% [markdown]
# # **5. Report**

# %%
print(summary_stats )
# Out:
#        test_score  study_hours
# count   15.000000    15.000000
# mean    84.133333     3.200000
# std      5.540328     1.859339
# min     75.000000     0.000000
# 25%     81.000000     2.000000
# 50%     84.000000     3.000000
# 75%     88.500000     4.000000
# max     92.000000     7.000000
